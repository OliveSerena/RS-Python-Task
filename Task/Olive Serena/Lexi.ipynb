# %%
s= input("Enter a string : ")
l= len(s)
for i in range(65,91):
  c=0
  for j in s:
    if j == chr(i):
     c=c+1
  if(c!=0):
   print(chr(i)," - ",c)

for k in range(97,123):
  c=0
  for l in s:
    if l ==chr(k) :
      c=c+1
  if(c!=0):
   print(chr(k)," - ",c)
# Out:
# Enter a string : Robotics
# R  -  1
# b  -  1
# c  -  1
# i  -  1
# o  -  2
# s  -  1
# t  -  1
